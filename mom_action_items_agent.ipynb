# %%
from google.colab import userdata
from huggingface_hub import login
from transformers import AutoTokenizer,AutoModelForCausalLM,BitsAndBytesConfig,TextStreamer
import openai
import requests
import os
import torch
from openai import OpenAI
from IPython.display import Markdown, display,update_display

# %%
# !pip install -U accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 9.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.2.1
#     Uninstalling accelerate-1.2.1:
#       Successfully uninstalled accelerate-1.2.1
# ...

# %%
hf_token=userdata.get('HF_TOKEN')
login(hf_token)

# %%
# prompt: code to load file from google drive

from google.colab import drive
drive.mount('/content/drive')
audio_file='/content/drive/My Drive/MyFolder/denver_extract.mp3'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
open_api_key=userdata.get("OPEN_API_KEY")
openai=OpenAI(api_key=open_api_key)

audio_file= open(audio_file, "rb")
transcription = openai.audio.transcriptions.create(
    model="whisper-1",
    file=audio_file,
    response_format="text"
)
print(transcription)
# Out:
# and kind of the confluence of this whole idea of the confluence week, the merging of two rivers and as we've kind of seen recently in politics and in the world, there's a lot of situations where water is very important right now and it's a very big issue. So that is the reason that the back of the logo is considered water. So let me see the creation of the logo here. So that basically kind of sums up the reason behind the logo and all the meanings behind the symbolism and you'll hear a little bit more about our confluence week is basically highlighting all of these indigenous events and things that are happening around Denver so that we can kind of bring more people together and kind of share this whole idea of Indigenous People's Day. So thank you. Thank you so much and thanks for your leadership. All right. Welcome to the Denver City Council meeting of Monday, October 9th. Please rise with the Pledge of Allegiance by Councilman Lopez. I pledge allegiance to the flag of the United S
# ...

# %%
system_message = "You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown."
user_prompt = f"Below is an extract transcript of a Denver council meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.\n{transcription}"

messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

def stream_response(stream):

    response = ""
    display_handle = display(Markdown(""), display_id=True)

    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```", "").replace("markdown", "")
        display_handle.update(Markdown(response))
    return response

# %%
moms=openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    stream=True
)

response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in moms:
  response += chunk.choices[0].delta.content or ''
  response = response.replace("```", "").replace("markdown", "")
  display_handle.update(Markdown(response))
# Out:
# # Denver City Council Meeting Minutes
#
# **Date:** October 9, 2017
# **Location:** Denver City Council Chambers
# **Attendees:**
# - Council Members: Bob Lopez (President), Espinosa, Flynn, Gilmour, Cashman, Kenneche, New, Ortega, Sussman, Clark
# - Clerk: (Name not provided)
#
# ---
#
# ## Summary
# The Denver City Council convened to celebrate the annual Indigenous Peoples Day and discuss the importance of Indigenous culture and contributions to the community. The meeting included a presentation of Proclamation No. 1127, which officially recognizes Indigenous Peoples Day in Denver and highlights the significance of Indigenous peoples' history, culture, and contributions.
#
# ---
#
# ## Key Discussion Points
# - **Confluence Week Events:** Introduction of the significance of Confluence Week, which celebrates Indigenous culture through various events around Denver.
# ...

# %%
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4"
)

# %%
tokenizer=AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")
tokenizer.pad_token = tokenizer.eos_token
inputs=tokenizer.apply_chat_template(messages,return_tensors="pt",return_dict=True).to("cuda")
model=AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct",device_map="auto",quantization_config=quant_config)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]

# %%
print(inputs)
# Out:
# {'input_ids': tensor([[128000, 128006,   9125,  ...,  27136,     13, 128009]],
#        device='cuda:0'), 'attention_mask': tensor([[1, 1, 1,  ..., 1, 1, 1]], device='cuda:0')}

# %%
streamer=TextStreamer(tokenizer,skip_prompt=True,skip_special_tokens=True)
outputs=model.generate(inputs["input_ids"],attention_mask=inputs["attention_mask"],streamer=streamer,max_new_tokens=1000)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# assistant
#
# **Meeting Minutes**
# ...
#
#
# ### Summary
#
# **Attendees:**
# - Councilman Lopez
# - Councilman Clark
# - Councilman Martega
# - Councilwoman Ortega
# - Councilwoman Kinneach
# - Clerk
# - Members of the Denver City Council
#
# **Location:**
# Denver City Council Chambers
#
# **Date:**
# Monday, October 9th
#
# **Summary:**
# The Denver City Council meeting on October 9th approved Proclamation 1127, Series of 2017, an observance of the second annual Indigenous Peoples Day in the City and County of Denver. The proclamation highlights the cultural and foundational contributions of Indigenous people to the city's history, present, and future.
#
# ### Discussion Points
#
# - The importance of Indigenous Peoples Day in celebrating the contributions of Indigenous people to the city and state.
# - The significance of the confluence of the two rivers, which created the Mile High City.
# ...

# %%
print(outputs[0])
response=tokenizer.decode(outputs[0])
print(response)
# Out:
# tensor([128000, 128006,   9125,  ...,   1968,     13, 128009], device='cuda:0')
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is an extract transcript of a Denver council meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.
# ...

# %%
display(Markdown(response))
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 Jul 2024
#
# You are an assistant that produces minutes of meetings from transcripts, with summary, key discussion points, takeaways and action items with owners, in markdown.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Below is an extract transcript of a Denver council meeting. Please write minutes in markdown, including a summary with attendees, location and date; discussion points; takeaways; and action items with owners.
# ...

# %%
openai.chat.

# %%
#
# Out:
# The label with the highest score is: technology
